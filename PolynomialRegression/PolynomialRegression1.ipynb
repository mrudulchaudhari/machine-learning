# %% [markdown]
# <a href="https://colab.research.google.com/github/mrudulchaudhari/machine-learning/blob/main/PolynomialRegression/PolynomialRegression1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %%
#load dataset
df = pd.read_csv("Position_Salaries.csv")
df.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
X = df[["Level"]]
y = df["Salary"]

# %%
plt.scatter(X, y, color="red")
plt.xlabel("Position level")
plt.ylabel("Salary")
plt.title("Position level vs Salary")
plt.plot()
# Out:
# []

# %%
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
X_grid = np.arange(min(X.values), max(X.values), 0.1).reshape(-1,1)
X_grid_poly = poly.transform(X_grid)
y_pred = model.predict(X_grid_poly)

plt.scatter(X, y, color='red')
plt.plot(X_grid, y_pred, color='blue')
plt.title('Polynomial Regression Fit')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()
# Out:
# /tmp/ipython-input-8-2726411079.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X.values), max(X.values), 0.1).reshape(-1,1)
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
poly = PolynomialFeatures(degree=3)
X_poly = poly.fit_transform(X)

model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
X_grid = np.arange(min(X.values), max(X.values), 0.1).reshape(-1,1)
X_grid_poly = poly.transform(X_grid)
y_pred = model.predict(X_grid_poly)

plt.scatter(X, y, color='red')
plt.plot(X_grid, y_pred, color='blue')
plt.title('Polynomial Regression Fit')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()
# Out:
# /tmp/ipython-input-10-2726411079.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X.values), max(X.values), 0.1).reshape(-1,1)
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
poly = PolynomialFeatures(degree=4)
X_poly = poly.fit_transform(X)

model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
X_grid = np.arange(min(X.values), max(X.values), 0.1).reshape(-1,1)
X_grid_poly = poly.transform(X_grid)
y_pred = model.predict(X_grid_poly)

plt.scatter(X, y, color='red')
plt.plot(X_grid, y_pred, color='blue')
plt.title('Polynomial Regression Fit')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()
# Out:
# /tmp/ipython-input-12-2726411079.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X.values), max(X.values), 0.1).reshape(-1,1)
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
model.predict(poly.transform([[6.5]]))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# array([158862.45265155])
